# %%
import os
os.chdir("../")

# %%
import pandas as pd

from src.utils.strava_utils import * 
from src.utils.utils import *

# %%
config = load_config_yaml()

# %%
access_token = get_access_token(config)
print(access_token)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.strava.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 6a756157ff9813948abadfc5a2ac97cf5fdf297a

# %%
header = {'Authorization': 'Bearer ' + access_token}
activities_per_page = 200
activities_url = config['strava']['activities_url']

all_activities = extract_all_strava_activities(activities_url, header, activities_per_page)
# Out:
# Added 184 activities. Total activities: 184
# No more activities found, breaking out of the loop.

# %%
all_activities
# Out:
# [{'resource_state': 2,
#   'athlete': {'id': 112963899, 'resource_state': 1},
#   'name': 'Evening HIIT',
#   'distance': 0.0,
#   'moving_time': 2010,
#   'elapsed_time': 2010,
#   'total_elevation_gain': 0,
#   'type': 'Workout',
#   'sport_type': 'Workout',
#   'id': 11983943278,
#   'start_date': '2024-07-25T18:39:54Z',
#   'start_date_local': '2024-07-25T19:39:54Z',
#   'timezone': '(GMT+01:00) Africa/Algiers',
#   'utc_offset': 3600.0,
#   'location_city': None,
#   'location_state': None,
#   'location_country': 'Portugal',
#   'achievement_count': 0,
#   'kudos_count': 0,
#   'comment_count': 0,
#   'athlete_count': 1,
#   'photo_count': 0,
#   'map': {'id': 'a11983943278', 'summary_polyline': '', 'resource_state': 2},
#   'trainer': True,
#   'commute': False,
#   'manual': False,
#   'private': False,
#   'visibility': 'followers_only',
#   'flagged': False,
#   'gear_id': None,
#   'start_latlng': [],
#   'end_latlng': [],
#   'average_speed': 0.0,
#   'max_speed': 0.0,
# ...

# %%
df = pd.json_normalize(all_activities)
df.head()
# Out:
#    resource_state                     name  distance  moving_time  \
# 0               2             Evening HIIT       0.0         2010
# 1               2  Evening Weight Training       0.0         1547
# 2               2          Evening Workout       0.0         1871
# 3               2          Morning Workout       0.0         1972
# 4               2             Evening Walk    2844.7         1988
#
#    elapsed_time  total_elevation_gain     type sport_type           id  \
# 0          2010                   0.0  Workout    Workout  11983943278
# 1          1547                   0.0  Workout    Workout  11971942620
# 2          1871                   0.0  Workout    Workout  11964337555
# 3          1972                   0.0  Workout    Workout  11916553016
# 4          2023                  14.2     Walk       Walk  11907682491
#
#              start_date  ... from_accepted_tag pr_count  total_photo_count  \
# ...
